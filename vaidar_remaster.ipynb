# %% [markdown]
# # Este libro sera utilizado para verificar las variables imputadas
#
# En el proceso de imputacion tendremos varias etapas y este reporte ayudara a mostrar el estado de cada serie remasterizada

# %%
import pandas as pd
serie_route = r"D:\master BigData\01 proyecto final\datos\IDEAM_ST\remaster\tumaco_ideam_remaster1.csv"
df = pd.read_csv(serie_route)
print(df)
# Out:
#           Fecha  IDEAM_complet
# 0    2017-01-01            3.0
# 1    2017-01-08            9.0
# 2    2017-01-15           12.0
# 3    2017-01-22            7.0
# 4    2017-01-29           14.0
# ..          ...            ...
# 309  2022-12-04           14.0
# 310  2022-12-11           16.0
# 311  2022-12-18           20.0
# 312  2022-12-25           16.0
# 313  2023-01-01           48.0
#
# [314 rows x 2 columns]

# %%
from cProfile import label
import matplotlib.pyplot as plt 

plt.figure(figsize=(8, 6))
plt.plot(df.index,df['IDEAM_complet'],label='prueba', color='blue')
plt.title('Prueba de validacion de serie en el tiempo')
plt.xlabel('Fechas', fontsize=20)
plt.ylabel('mm', fontsize=20)
plt.legend()
plt.grid(True)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
